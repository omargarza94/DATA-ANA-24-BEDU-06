# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

FILENAME = 'Ejemplo_02_03_Cybersecurity_Dataset.csv'

# Cargar nuestro dataset

cybersecurity_data = pd.read_csv(FILENAME)
cybersecurity_data.head()
# Out:
#    attack_type  severity  response_time
# 0   Ransomware         4            2.8
# 1  Brute Force         9           11.6
# 2      Malware         6            4.7
# 3  Brute Force         3            2.0
# 4  Brute Force         1            1.8

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

FILENAME = 'Ejemplo_02_03_Cybersecurity_Dataset.csv'

# Cargar nuestro dataset
cybersecurity_data = pd.read_csv(FILENAME)
cybersecurity_data.head()

# FacetGrid crea una cuadricula de scatterplots, esta basado en subconjuntos de la columna attack_type
g = sns.FacetGrid(cybersecurity_data, col='attack_type', col_wrap=3, height=4)
g.map(sns.scatterplot, 'severity', 'response_time', color='b')

g.fig.suptitle('Severidad VS Tiempo de respuesta en ataques de ciber seguridad', fontsize=14)
g.fig.tight_layout(rect=[0, 0, 1, 0.95])


# mostrar grafico
plt.show()
